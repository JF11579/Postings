# %% [markdown]
# <a href="https://colab.research.google.com/github/JF11579/Postings/blob/main/Contemporaries_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### At this point in separete plots we have the labelssl correct, the historical incidents correct,  and the names alphabetized, and the Legend correct.
#
# This notebook is about bringing them all together

# %% [markdown]
# # Libraries

# %%
#pip install fastapi

# %%
#pip install kaleido

# %%
#!pip install plotly --upgrade

# %%
import pandas as pd
import plotly.express as px
from google.colab import drive
import numpy as np

# %% [markdown]
# # Data

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change to the directory containing your CSV
#%cd /content/drive/MyDrive/DATA/Real_Estate_Data
# %cd /content/drive/MyDrive/Colab Notebooks/Projects/Plotly/General
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Projects/Plotly/General

# %%
data_people = pd.read_csv('Contemporaries_2.1.csv')
# Load data for events
#data_events = pd.read_csv('Contemp_Events_3.csv')

# %%
data_people.head(50)
# Out:
#                        Name  Born  Died                 Field  \
# 0           Abraham Lincoln  1809  1865            Politician
# 1        Alexander Hamilton  1755  1804            Politician
# 2                 Bonaparte  1769  1821            Politician
# 3              Buffalo Bill  1846  1917                Artist
# 4            Charles Darwin  1809  1882  Engineer~ Scienctist
# 5           Charles Dickens  1812  1870                Artist
# 6                 Churchill  1874  1965            Politician
# 7              Clara Barton  1821  1912       Social Activist
# 8                    Eiffel  1832  1923  Engineer~ Scienctist
# 9                  Einstein  1879  1955  Engineer~ Scienctist
# 10     Florence Nightingale  1820  1910       Social Activist
# 11       Frank Lloyd Wright  1867  1959                Artist
# 12       Frederick Douglass  1818  1895       Social Activist
# 13                    Freud  1856  1939                Artist
# ...

# %% [markdown]
# # Plot

# %%
# 18

import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
    font_color='white',  # Set the text color for the entire figure
)

# Add event annotations
# ...

# Add text box with color information using HTML annotation
color_info_text = (
    "<b>Color Information:</b><br>"
    "Soldier = grey<br>"
    "Politician = red<br>"
    "Artist = yellow<br>"
    "Social Activist = purple<br>"
    "Engineer~Science = green"
)

fig.add_annotation(
    go.layout.Annotation(
        x=0.96,
        y=1.05,
        xref='paper',
        yref='paper',
        text=color_info_text,
        showarrow=False,
        font=dict(color='black', size=12),
        align='center',
        bordercolor='black',
        borderwidth=2,
        bgcolor='rgba(255,255,255,0.7)',
    )
)

################################################################################
#                        World War One (1914-1918)
fig.add_shape(
    type='rect',
    x0='1914-01-01',
    x1='1918-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>One',
    x='1916-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
################################################################################
################################################################################
#                    Add a vertical band for WW2

fig.add_shape(
    type='rect',
    x0='1939-01-01',
    x1='1945-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>Two',
    x='1942-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

############################################################################
##############################################################################
#                      American Civil War

fig.add_shape(
    type='rect',
    x0='1861-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>American<br>Civil<br>War',
    x='1863-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) *-0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
################################################################################
##############################################################################
#                        Tulsa Race Riot

fig.add_shape(
    type='rect',
    x0='1921-01-01',
    x1='1923-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Tulsa<br>Race<br>Riot</b>',
    x='1922-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 1.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14, family='Arial, sans-serif'),  # Set the text size and family
)

##############################################################################
##############################################################################
#                          FIRST FLIGHT
fig.add_shape(
    type='rect',
    x0='1903-01-01',
    x1='1905-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Flight<br>',
    x='1904-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

############################################################################




#    #    #


# Remove the legend
fig.update_layout(showlegend=False)

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 17

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
    font_color='white',  # Set the text color for the entire figure
)

# Add event annotations
# ...

# Add text box with color information
color_info_text = (
    "Soldier = grey\n"
    "Politician = red\n"
    "Artist = yellow\n"
    "Social Activist = purple\n"
    "Engineer~Science = green"
)

fig.add_trace(
    go.Scatter(
        x=[],
        y=[],
        mode='text',
        text=[color_info_text],
        textposition='middle right',
        showlegend=False
    )
)

# Remove the legend
fig.update_layout(showlegend=False)

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 16

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
    font_color='white',  # Set the text color for the entire figure
)

# Add event annotations
# ...

# Add text box with color information
color_info_text = (
    "Soldier = grey\n"
    "Politician = red\n"
    "Artist = yellow\n"
    "Social Activist = purple\n"
    "Engineer~Science = green"
)

fig.add_annotation(
    go.layout.Annotation(
        text=color_info_text,
        align='left',
        showarrow=False,
        xref='paper',
        yref='paper',
        x=0.05,
        y=0.95,
        bordercolor='black',
        borderwidth=2,
        bgcolor='rgba(255,255,255,0.7)',
        font=dict(color='black', size=12),
    )
)

# Remove the legend
fig.update_layout(showlegend=False)

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 15

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Define colors and labels for legend
legend_labels = {
    "Soldier": "grey",
    "Politician": "red",
    "Artist": "yellow",
    "Social Activist": "purple",
    "Engineer~Science": "green",
}

# Define a custom legend title based on the dictionary keys
legend_title = "Occupations by Color:"

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Add legend entries for occupations with customized legend text
for label, color in legend_labels.items():
    legend_text = f"{label} - {color}"  # Customize the legend text as needed
    fig.add_trace(
        go.Scatter(
            x=[None],
            y=[None],
            mode="markers",
            marker=dict(color=color, size=10),  # Adjust size as needed
            showlegend=True,
            legendgroup=label,
            name=legend_text,  # Use the customized legend text
        )
    )

# Set legend order
fig.update_layout(
    legend_title=legend_title,
    legend=dict(traceorder="normal"),  # Set trace order to normal
    # Other layout customizations...
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
   title='Famous People Timeline with Events',
   xaxis_title='Years',
   yaxis_title='Name',
   height=800,
   width=1200,
   plot_bgcolor='darkblue',  # Set the background color behind the plot
   paper_bgcolor='darkblue',
   font_color='white',  # Set the text color for the entire figure# Set the background color of the entire figure
)

# Add event annotations
# ...

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#14

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Define colors and labels for legend
legend_labels = {
    "Soldier": "grey",
    "Politician": "red",
    "Artist": "yellow",
    "Social Activist": "purple",
    "Engineer~Science": "green",
}

# Define a custom legend title based on the dictionary keys
legend_title = "Occupations by Color:"

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Add legend entries for occupations
for label, color in legend_labels.items():
    fig.add_trace(
        go.Scatter(
            x=[None],
            y=[None],
            mode="markers",
            marker=dict(color=color, size=10),  # Adjust size as needed
            showlegend=True,
            legendgroup=label,
            name=label,
        )
    )

# Remove the first 6 legend entries
fig.for_each_trace(lambda t: t.update(showlegend=False) if t.name in list(legend_labels.keys())[:6] else ())

# Set legend order
fig.update_layout(
    legend_title=legend_title,
    legend=dict(traceorder="normal"),  # Set trace order to normal
    # Other layout customizations...
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
   title='Famous People Timeline with Events',
   xaxis_title='Years',
   yaxis_title='Name',
   height=800,
   width=1200,
   plot_bgcolor='darkblue',  # Set the background color behind the plot
   paper_bgcolor='darkblue',
   font_color='white',  # Set the text color for the entire figure# Set the background color of the entire figure
)

# Add event annotations
# ...

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 13

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Define colors and labels for legend
legend_labels = {
    "Soldier": "grey",
    "Politician": "red",
    "Artist": "yellow",
    "Social Activist": "purple",
    "Engineer~Science": "green",
}

# Define a custom legend title based on the dictionary keys
legend_title = "Occupations by Color:"

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Add legend entries for occupations
for label, color in legend_labels.items():
    fig.add_trace(
        go.Scatter(
            x=[None],
            y=[None],
            mode="markers",
            marker=dict(color=color, size=10),  # Adjust size as needed
            showlegend=True,
            legendgroup=label,
            name=label,
        )
    )

# Set legend order
fig.update_layout(
    legend_title=legend_title,
    legend=dict(traceorder="normal"),  # Set trace order to normal
    # Other layout customizations...
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
   title='Famous People Timeline with Events',
   xaxis_title='Years',
   yaxis_title='Name',
   height=800,
   width=1200,
   plot_bgcolor='darkblue',  # Set the background color behind the plot
   paper_bgcolor='darkblue',
    font_color='white',  # Set the text color for the entire figure# Set the background color of the entire figure
)
################


##########

# Add event annotations
# ...

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 12

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Define colors and labels for legend
legend_labels = {
    "Soldier": "grey",
    "Politician": "red",
    "Artist": "yellow",
    "Social Activist": "darkgreen",
    "Engineer~Science": "green",
}

# Build a string of color labels separated by commas
legend_text = ", ".join([color for _, color in legend_labels.items()])

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Add legend entries for occupations
for label, color in legend_labels.items():
    fig.add_trace(
        go.Scatter(
            x=[None],
            y=[None],
            mode="none",  # Hide markers
            marker=dict(color=color, size=0),
            showlegend=True,
            legendgroup=label,
            name=label,
        )
    )

# Set legend order
fig.update_layout(
    legend_title_text=legend_text,
    # Other layout customizations...
)

# Add event annotations
# ...

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 11

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Define colors and labels for legend
legend_labels = {
    "Soldier": "grey",
    "Politician": "red",
    "Artist": "yellow",
    "Social Activist": "darkgreen",
    "Engineer~Science": "green",
}

# Define a custom legend title based on the dictionary keys
legend_title = "Occupations by Color:"

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Add legend entries for occupations
for label, color in legend_labels.items():
    fig.add_trace(
        go.Scatter(
            x=[None],
            y=[None],
            mode="none",  # Hide markers
            marker=dict(color=color, size=0),
            showlegend=True,
            legendgroup=label,
            name=label,
        )
    )

# Set legend order
fig.update_layout(
    legend_title=legend_title,
    # Other layout customizations...
)

# Add event annotations
# ...

# Show the chart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 10

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name", ascending=False)

# Define colors and labels for legend
legend_labels = {
    "Soldier": "grey",
    "Politician": "red",
    "Artist": "yellow",
    "Social Activist": "darkgreen",
    "Engineer~Science": "green",
}

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Add legend entries for occupations
for label, color in legend_labels.items():
    fig.add_trace(
        go.Scatter(
            x=[None],
            y=[None],
            mode="none",  # Hide markers
            marker=dict(color=color, size=0),
            showlegend=True,
            legendgroup=label,
            name=label,
        )
    )

# Set legend order
fig.update_layout(
    legend_title_text=[color for _, color in legend_labels.items()],
)


# Add event annotations
fig.add_shape(
    type="rect",
    x0="1914-01-01",
    x1="1918-12-31",
    y0=0,
    y1=len(data_people["Name"]),
    fillcolor="rgba(255, 0, 0, 0.2)",
    line=dict(color="red", width=2),
    layer="below",
)
fig.add_annotation(
    text="<b>World<br>War<br>One",
    x="1916-06-15",  # Adjust the x-coordinate for label placement
    y=len(data_people["Name"]) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color="white", size=14),  # Set the text size
)

# More event annotations follow the same pattern as above

# Customize the layout
fig.update_layout(
    title="Famous People Timeline with Events",
    xaxis_title="Years",
    yaxis_title="Name",
    height=800,
    width=1200,
    plot_bgcolor="darkblue",  # Set the background color behind the plot
    paper_bgcolor="darkblue",  # Set the background color of the entire figure
    font_color="white",  # Set the text color for the entire figure
    legend=dict(
        title="Occupations",
        orientation="h",
        y=1.05,  # Adjust y position slightly above the chart
        yanchor="bottom",
        x=0.5,  # Center the legend horizontally
        xanchor="center",
    ),
)

# Show the chart
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-5693e64d18df> in <cell line: 56>()
#      54
#      55 # Set legend order
# ---> 56 fig.update_layout(
#      57     legend_title_text=[color for _, color in legend_labels.items()],
#      58 )
#
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objs/_figure.py in update_layout(self, dict1, overwrite, **kwargs)
#     773
#     774         """
# --> 775         return super(Figure, self).update_layout(dict1, overwrite, **kwargs)
#     776
#     777     def for_each_trace(
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in update_layout(self, dict1, overwrite, **kwargs)
#    1391             The Figure object that the update_layout method was called on
#    1392         """
# -> 1393         self.layout.update(dict1, overwrite=overwrite, **kwargs)
#    1394         return self
#    1395
#
# ...

# %%
# 9

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

#           Sort the names
# Sort the data by the 'Name' column in alphabetical order
#data_people = data_people.sort_values(by='Name', ascending=False)
data_people = data_people.sort_values(by='Name', ascending=False)



# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Create the Gantt chart with color mapping based on the 'Field_Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

################################################################################
#                        World War One (1914-1918)
fig.add_shape(
    type='rect',
    x0='1914-01-01',
    x1='1918-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='red', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>One',
    x='1916-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
################################################################################
#                    Add a vertical band for WW2

fig.add_shape(
    type='rect',
    x0='1939-01-01',
    x1='1945-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='red', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>Two',
    x='1942-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

##############################################################################
#                          FIRST FLIGHT
fig.add_shape(
    type='rect',
    x0='1903-01-01',
    x1='1905-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Flight<br>',
    x='1904-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.54,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

###############################################################################
#                    FIRST PHONE CALL

fig.add_shape(
    type='rect',
    x0='1876-01-01',
    x1='1878-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Phone<br>Call',
    x='1877-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.55,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################

##############################################################################
#                      American Civil War

fig.add_shape(
    type='rect',
    x0='1861-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>American<br>Civil<br>War',
    x='1863-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) *0.6,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                       Emancipation Proclamation

fig.add_shape(
    type='rect',
    x0='1863-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Emancipation<br>Proclamation<br>',
    x='1864-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.86,  # Adjust the y-coordinate for label placement (e.g., 0.9 is 90% of the height)
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                        Tulsa Race Riot

fig.add_shape(
    type='rect',
    x0='1921-01-01',
    x1='1923-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Tulsa<br>Race<br>Riot</b>',
    x='1922-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.79,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14, family='Arial, sans-serif'),  # Set the text size and family
)

##############################################################################
# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
     font_color='white',  # Set the text color for the entire figure# Set the background color of the entire figure
)


# # Customize the chart appearance, including setting the background color
# fig.update_layout(
#     title='Famous People Timeline with Events',
#     xaxis_title='Years',
#     yaxis_title='Name',
#     height=800,
#     width=1200,
#     plot_bgcolor='blue',  # Set the background color
# )

# Show the chart
fig.show()

# %%
# 8
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Data paths
data_people_path = "ConvertToDF_2_1.csv"
data_events_path = "Contemp_Events_3.csv"

# Read data
data_people = pd.read_csv(data_people_path)
data_events = pd.read_csv(data_events_path)

# Convert dates
data_people["Born"] = pd.to_datetime(data_people["Born"], format="%Y")
data_people["Died"] = pd.to_datetime(data_people["Died"], format="%Y")

# Sort data
data_people = data_people.sort_values(by="Name")

# Define colors and labels for legend
legend_labels = {
    "Soldier": "grey",
    "Politician": "red",
    "Artist": "yellow",
    "Social Activist": "darkgreen",
    "Engineer~Science": "green",
}

# Create the timeline
fig = px.timeline(
    data_people,
    x_start="Born",
    x_end="Died",
    y="Name",
    color="Field_Color",  # Use color column for bar colors
    category_orders={"Name": data_people["Name"].tolist()},  # Explicitly set category order
)

# Add event annotations
fig.add_shape(
    type="rect",
    x0="1914-01-01",
    x1="1918-12-31",
    y0=0,
    y1=len(data_people["Name"]),
    fillcolor="rgba(255, 0, 0, 0.2)",
    line=dict(color="black", width=3),
    layer="below",
)
fig.add_annotation(
    text="<b>World<br>War<br>One",
    x="1916-06-15",
    y=len(data_people["Name"]) * 1.1,
    showarrow=False,
    font=dict(color="white", size=14),
)

# Add more event annotations here (follow the same pattern)

# Add custom legend entries
for label, color in legend_labels.items():
    fig.add_trace(
        go.Scatter(
            x=[None],
            y=[None],
            mode="none",  # Hide markers
            marker=dict(color=color, size=0),
            showlegend=True,
            legendgroup=label,
            name=label,
        )
    )

# Hide default legend entries
fig.update_layout(showlegend=False)

# Customize the layout
fig.update_layout(
    title="Famous People Timeline with Events",
    xaxis_title="",
    yaxis_title="",
    height=800,
    width=1200,
    plot_bgcolor="blue",  # Set background color behind the plot
    paper_bgcolor="blue",
    font_color="white",  # Set text color for the entire figure
)

fig_layout = go.Layout(
    title="Famous People Timeline with Events",
    xaxis_title="",
    yaxis_title="",
    height=800,
    width=1200,
    plot_bgcolor="blue",
    paper_bgcolor="blue",
    font_color="white",
)

fig_legend = go.Figure(
    layout=go.Layout(legend=dict(title="Occupations", orientation="v"))
)

fig_combined = go.Figure(
    data=fig.data,
    layout=fig_layout,
    for_subplot_use=True,
)

fig_combined.add_layout(fig_legend, "below", x=0.5, y=0.1, xanchor="center")  # Adjust legend position

fig_combined.show()


# fig.update_layout(
#     legend=dict(
#         title="Occupations",
#         orientation="h",
#         y= .05,  # Adjust y position slightly above the chart
#         yanchor="bottom",
#         x=0.5,  # Center the legend horizontally
#         xanchor="center",
#     )
# )

# Show the chart
#fig.show()

# %%
# 7

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Sort the data by the 'Name' column in alphabetical order
data_people = data_people.sort_values(by='Name')

# Create the Gantt chart with color mapping based on the 'Field Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
    category_orders={'Name': data_people['Name'].tolist()},  # Explicitly set category order
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

################################################################################
#                        World War One (1914-1918)
fig.add_shape(
    type='rect',
    x0='1914-01-01',
    x1='1918-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>One',
    x='1916-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 1.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
################################################################################
#                    Add a vertical band for WW2

fig.add_shape(
    type='rect',
    x0='1939-01-01',
    x1='1945-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>Two',
    x='1942-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

##############################################################################
#                          FIRST FLIGHT
fig.add_shape(
    type='rect',
    x0='1903-01-01',
    x1='1905-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Flight<br>',
    x='1904-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

###############################################################################
#                    FIRST PHONE CALL

fig.add_shape(
    type='rect',
    x0='1876-01-01',
    x1='1878-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Phone<br>Call',
    x='1877-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################

##############################################################################
#                      American Civil War

fig.add_shape(
    type='rect',
    x0='1861-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>American<br>Civil<br>War',
    x='1863-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) *-0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                       Emancipation Proclamation

fig.add_shape(
    type='rect',
    x0='1863-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Emancipation<br>Proclamation<br>',
    x='1864-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 1.1,  # Adjust the y-coordinate for label placement (e.g., 0.9 is 90% of the height)
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                        Tulsa Race Riot

fig.add_shape(
    type='rect',
    x0='1921-01-01',
    x1='1923-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Tulsa<br>Race<br>Riot</b>',
    x='1922-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14, family='Arial, sans-serif'),  # Set the text size and family
)

##############################################################################

# Customize the legend
legend_labels = {
    'Politician': 'red',
    'Artist': 'yellow',
    'Social Activist': 'darkgreen',
    'Engineer~Science': 'green',
    'Soldier': 'grey',
}

# Add custom legend entries  <<<<<<<<<<<<<<<<<<<<----------------
for label, color in legend_labels.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(color=color, size=2),  # Set size to 0 to hide markers
        showlegend=True,
        legendgroup=label,
        name=label,
    ))


# Hide default legend entries
fig.update_layout(showlegend=False)

# ... (rest of your code)

# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='',
    yaxis_title='',
    height=800,
    width=1200,
    plot_bgcolor='blue',  # Set the background color behind the plot
    paper_bgcolor='blue',
    font_color='white',  # Set the text color for the entire figure
)

#################################
################################
# ... (your existing code)

# Customize the legend
legend_labels = {
    'Politician': 'red',
    'Artist': 'yellow',
    'Social Activist': 'purple',  # Adjust the color for Social Activist to purple
    'Engineer~Science': 'green',
    'Soldier': 'grey',
}

# Add custom legend entries
for label, color in legend_labels.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(color=color, size=10),
        showlegend=True,
        legendgroup=label,
        name=label,
    ))

# Hide default legend entries
fig.update_layout(showlegend=False)

# ... (rest of your code)

# Add a legend manually
fig.update_layout(
    legend=dict(
        traceorder='normal',
        font=dict(size=12),
        itemsizing='constant',
        title=dict(text='Legend'),
        items=[dict(label=key, marker=dict(color=value)) for key, value in legend_labels.items()],
    ),
)

# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='',
    yaxis_title='',
    xaxis=dict(tickvals=[]),
    yaxis=dict(tickvals=[]),
    height=800,
    width=1200,
    plot_bgcolor='blue',
    paper_bgcolor='blue',
    font_color='white',
)

# Show the chart
fig.show()

# %%
# 6

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Sort the data by the 'Name' column in alphabetical order
data_people = data_people.sort_values(by='Name')

# Create the Gantt chart with color mapping based on the 'Field Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
    category_orders={'Name': data_people['Name'].tolist()},  # Explicitly set category order
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

################################################################################
#                        World War One (1914-1918)
fig.add_shape(
    type='rect',
    x0='1914-01-01',
    x1='1918-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>One',
    x='1916-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 1.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
################################################################################
#                    Add a vertical band for WW2

fig.add_shape(
    type='rect',
    x0='1939-01-01',
    x1='1945-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>Two',
    x='1942-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

##############################################################################
#                          FIRST FLIGHT
fig.add_shape(
    type='rect',
    x0='1903-01-01',
    x1='1905-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Flight<br>',
    x='1904-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

###############################################################################
#                    FIRST PHONE CALL

fig.add_shape(
    type='rect',
    x0='1876-01-01',
    x1='1878-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Phone<br>Call',
    x='1877-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################

##############################################################################
#                      American Civil War

fig.add_shape(
    type='rect',
    x0='1861-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>American<br>Civil<br>War',
    x='1863-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) *-0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                       Emancipation Proclamation

fig.add_shape(
    type='rect',
    x0='1863-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Emancipation<br>Proclamation<br>',
    x='1864-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 1.1,  # Adjust the y-coordinate for label placement (e.g., 0.9 is 90% of the height)
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                        Tulsa Race Riot

fig.add_shape(
    type='rect',
    x0='1921-01-01',
    x1='1923-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Tulsa<br>Race<br>Riot</b>',
    x='1922-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14, family='Arial, sans-serif'),  # Set the text size and family
)

##############################################################################

# Customize the legend
legend_labels = {
    'Politician': 'red',
    'Artist': 'yellow',
    'Social Activist': 'darkgreen',
    'Engineer~Science': 'green',
    'Soldier': 'grey',
}

# Add custom legend entries  <<<<<<<<<<<<<<<<<<<<----------------
for label, color in legend_labels.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(color=color, size=2),  # Set size to 0 to hide markers
        showlegend=True,
        legendgroup=label,
        name=label,
    ))


# Hide default legend entries
fig.update_layout(showlegend=False)

# ... (rest of your code)

# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='',
    yaxis_title='',
    height=800,
    width=1200,
    plot_bgcolor='blue',  # Set the background color behind the plot
    paper_bgcolor='blue',
    font_color='white',  # Set the text color for the entire figure
)

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 6

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Sort the data by the 'Name' column in alphabetical order
data_people = data_people.sort_values(by='Name')

# Create the Gantt chart with color mapping based on the 'Field Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
    category_orders={'Name': data_people['Name'].tolist()},  # Explicitly set category order
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

################################################################################
#                        World War One (1914-1918)
fig.add_shape(
    type='rect',
    x0='1914-01-01',
    x1='1918-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>One',
    x='1916-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 1.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
################################################################################
#                    Add a vertical band for WW2

fig.add_shape(
    type='rect',
    x0='1939-01-01',
    x1='1945-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>Two',
    x='1942-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

##############################################################################
#                          FIRST FLIGHT
fig.add_shape(
    type='rect',
    x0='1903-01-01',
    x1='1905-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Flight<br>',
    x='1904-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

###############################################################################
#                    FIRST PHONE CALL

fig.add_shape(
    type='rect',
    x0='1876-01-01',
    x1='1878-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Phone<br>Call',
    x='1877-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################

##############################################################################
#                      American Civil War

fig.add_shape(
    type='rect',
    x0='1861-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>American<br>Civil<br>War',
    x='1863-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) *-0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                       Emancipation Proclamation

fig.add_shape(
    type='rect',
    x0='1863-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Emancipation<br>Proclamation<br>',
    x='1864-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 1.1,  # Adjust the y-coordinate for label placement (e.g., 0.9 is 90% of the height)
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                        Tulsa Race Riot

fig.add_shape(
    type='rect',
    x0='1921-01-01',
    x1='1923-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='black', width=3),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Tulsa<br>Race<br>Riot</b>',
    x='1922-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * -0.1,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14, family='Arial, sans-serif'),  # Set the text size and family
)

##############################################################################

# Customize the legend
legend_labels = {
    'Politician': 'red',
    'Artist': 'yellow',
    'Social Activist': 'darkgreen',
    'Engineer~Science': 'green',
    'Soldier': 'grey',
}

# Add custom legend entries  <<<<<<<<<<<<<<<<<<<<----------------
for label, color in legend_labels.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(color=color, size=2),  # Set size to 0 to hide markers
        showlegend=True,
        legendgroup=label,
        name=label,
    ))


# Hide default legend entries
fig.update_layout(showlegend=False)

# ... (rest of your code)

# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='',
    yaxis_title='',
    height=800,
    width=1200,
    plot_bgcolor='blue',  # Set the background color behind the plot
    paper_bgcolor='blue',
    font_color='white',  # Set the text color for the entire figure
)

# Show the chart
fig.show()

# %%
#5

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

#           Sort the names
# Sort the data by the 'Name' column in alphabetical order
#data_people = data_people.sort_values(by='Name', ascending=False)
data_people = data_people.sort_values(by='Name', ascending=False)



# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Create the Gantt chart with color mapping based on the 'Field_Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

################################################################################
#                        World War One (1914-1918)
fig.add_shape(
    type='rect',
    x0='1914-01-01',
    x1='1918-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='red', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>One',
    x='1916-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
################################################################################
#                    Add a vertical band for WW2

fig.add_shape(
    type='rect',
    x0='1939-01-01',
    x1='1945-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='red', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>Two',
    x='1942-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

##############################################################################
#                          FIRST FLIGHT
fig.add_shape(
    type='rect',
    x0='1903-01-01',
    x1='1905-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Flight<br>',
    x='1904-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.54,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

###############################################################################
#                    FIRST PHONE CALL

fig.add_shape(
    type='rect',
    x0='1876-01-01',
    x1='1878-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Phone<br>Call',
    x='1877-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.55,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################

##############################################################################
#                      American Civil War

fig.add_shape(
    type='rect',
    x0='1861-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>American<br>Civil<br>War',
    x='1863-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) *0.6,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                       Emancipation Proclamation

fig.add_shape(
    type='rect',
    x0='1863-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Emancipation<br>Proclamation<br>',
    x='1864-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.86,  # Adjust the y-coordinate for label placement (e.g., 0.9 is 90% of the height)
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                        Tulsa Race Riot

fig.add_shape(
    type='rect',
    x0='1921-01-01',
    x1='1923-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Tulsa<br>Race<br>Riot</b>',
    x='1922-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.79,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14, family='Arial, sans-serif'),  # Set the text size and family
)

##############################################################################
# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
     font_color='white',  # Set the text color for the entire figure# Set the background color of the entire figure
)


# # Customize the chart appearance, including setting the background color
# fig.update_layout(
#     title='Famous People Timeline with Events',
#     xaxis_title='Years',
#     yaxis_title='Name',
#     height=800,
#     width=1200,
#     plot_bgcolor='blue',  # Set the background color
# )

# Show the chart
fig.show()

# %%
#4

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Sort the data by the 'Name' column in alphabetical order
data_people = data_people.sort_values(by='Name')

# Create the Gantt chart with color mapping based on the 'Field Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
    category_orders={'Name': data_people['Name'].tolist()},  # Explicitly set category order
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

# Customize the legend
legend_labels = {
    'Politician': 'red',
    'Artist': 'yellow',
    'Social Activist': 'darkgreen',
    'Engineer~Science': 'green',
    'Soldier': 'grey',
}

# Add custom legend entries
for label, color in legend_labels.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(color=color),
        showlegend=True,
        legendgroup=label,
        name=label,
    ))

# Remove default legend entries, excluding the top row
for trace in fig.data[:5]:
    trace.showlegend = False

################################################################################
#                        World War One (1914-1918)
fig.add_shape(
    type='rect',
    x0='1914-01-01',
    x1='1918-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='red', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>One',
    x='1916-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=16),  # Set the text size
)
################################################################################
################################################################################
#                    Add a vertical band for WW2

fig.add_shape(
    type='rect',
    x0='1939-01-01',
    x1='1945-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='red', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>Two',
    x='1942-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=16),  # Set the text size
)

##############################################################################
##############################################################################
#                          FIRST FLIGHT
fig.add_shape(
    type='rect',
    x0='1903-01-01',
    x1='1905-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Flight<br>',
    x='1904-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.54,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=16),  # Set the text size
)

###############################################################################
###############################################################################
#                    FIRST PHONE CALL

fig.add_shape(
    type='rect',
    x0='1876-01-01',
    x1='1878-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Phone<br>Call',
    x='1877-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.35,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=16),  # Set the text size
)
##############################################################################
##############################################################################
#                      American Civil War

fig.add_shape(
    type='rect',
    x0='1861-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>American<br>Civil<br>War',
    x='1863-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) *0.6,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=16),  # Set the text size
)
##############################################################################
##############################################################################
#                       Emancipation Proclamation

fig.add_shape(
    type='rect',
    x0='1863-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Emancipation<br>Proclamation<br>',
    x='1864-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.94,  # Adjust the y-coordinate for label placement (e.g., 0.9 is 90% of the height)
    showarrow=False,
    font=dict(color='white', size=16),  # Set the text size
)
##############################################################################
##############################################################################
#                        Tulsa Race Riot

fig.add_shape(
    type='rect',
    x0='1921-01-01',
    x1='1923-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Tulsa<br>Race<br>Riot</b>',
    x='1922-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.79,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=16, family='Arial, sans-serif'),  # Set the text size and family
)

##############################################################################

# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
    font_color='white',  # Set the text color for the entire figure
)

# Show the chart
fig.show()

# %%
#3

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Sort the data by the 'Name' column in alphabetical order
data_people = data_people.sort_values(by='Name')

# Create the Gantt chart with color mapping based on the 'Field Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
    category_orders={'Name': data_people['Name'].tolist()},  # Explicitly set category order
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

# Customize the legend
legend_labels = {
    'Politician': 'red',
    'Artist': 'yellow',
    'Social Activist': 'darkgreen',
    'Engineer~Science': 'green',
    'Soldier': 'grey',
}

for label, color in legend_labels.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(color=color),
        showlegend=True,
        legendgroup=label,
        name=label,
    ))

# ... (rest of your code)

# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
    font_color='white',  # Set the text color for the entire figure
)

# Show the chart
fig.show()

# %%
# 2

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Sort the data by the 'Name' column in alphabetical order
data_people = data_people.sort_values(by='Name')

# Create the Gantt chart with color mapping based on the 'Field Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
    category_orders={'Name': data_people['Name'].tolist()},  # Explicitly set category order
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

# ... (rest of your code)

# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
    font_color='white',  # Set the text color for the entire figure
)

# Show the chart
fig.show()

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

############### DATA  ###################################
data_people = pd.read_csv('ConvertToDF_2_1.csv')        #
# Load data for events                                  #
data_events = pd.read_csv('Contemp_Events_3.csv')       #
#########################################################

# Convert the born and died dates to datetime format
data_people['Born'] = pd.to_datetime(data_people['Born'], format='%Y')
data_people['Died'] = pd.to_datetime(data_people['Died'], format='%Y')

# Sort the data by the 'Name' column in alphabetical order
data_people = data_people.sort_values(by='Name')

# Create the Gantt chart with color mapping based on the 'Field_Color' column
fig = px.timeline(
    data_people,
    x_start='Born',
    x_end='Died',
    y='Name',
    color='Field_Color',  # Use the 'Field_Color' column for color mapping
)

# Convert the start and end dates to datetime format
data_events['Start'] = pd.to_datetime(data_events['Start'])
data_events['End'] = pd.to_datetime(data_events['End'])

################################################################################
#                        World War One (1914-1918)
fig.add_shape(
    type='rect',
    x0='1914-01-01',
    x1='1918-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='red', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>One',
    x='1916-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
################################################################################
#                    Add a vertical band for WW2

fig.add_shape(
    type='rect',
    x0='1939-01-01',
    x1='1945-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='red', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>World<br>War<br>Two',
    x='1942-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.31,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

##############################################################################
#                          FIRST FLIGHT
fig.add_shape(
    type='rect',
    x0='1903-01-01',
    x1='1905-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Flight<br>',
    x='1904-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.54,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)

###############################################################################
#                    FIRST PHONE CALL

fig.add_shape(
    type='rect',
    x0='1876-01-01',
    x1='1878-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>First<br>Phone<br>Call',
    x='1877-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.55,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################

##############################################################################
#                      American Civil War

fig.add_shape(
    type='rect',
    x0='1861-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>American<br>Civil<br>War',
    x='1863-06-15',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) *0.6,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                       Emancipation Proclamation

fig.add_shape(
    type='rect',
    x0='1863-01-01',
    x1='1865-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Emancipation<br>Proclamation<br>',
    x='1864-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.86,  # Adjust the y-coordinate for label placement (e.g., 0.9 is 90% of the height)
    showarrow=False,
    font=dict(color='white', size=14),  # Set the text size
)
##############################################################################
#                        Tulsa Race Riot

fig.add_shape(
    type='rect',
    x0='1921-01-01',
    x1='1923-12-31',
    y0=0,
    y1=len(data_people['Name']),
    fillcolor='rgba(255, 0, 0, 0.2)',
    line=dict(color='green', width=2),
    layer='below',
)

# Add a label to the vertical bar with line breaks and bold text
fig.add_annotation(
    text='<b>Tulsa<br>Race<br>Riot</b>',
    x='1922-01-01',  # Adjust the x-coordinate for label placement
    y=len(data_people['Name']) * 0.79,  # Adjust the y-coordinate for label placement
    showarrow=False,
    font=dict(color='white', size=14, family='Arial, sans-serif'),  # Set the text size and family
)

##############################################################################
# Customize the chart appearance
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
)

# Customize the chart appearance, including setting the background color
fig.update_layout(
    title='Famous People Timeline with Events',
    xaxis_title='Years',
    yaxis_title='Name',
    height=800,
    width=1200,
    plot_bgcolor='darkblue',  # Set the background color behind the plot
    paper_bgcolor='darkblue',
     font_color='white',  # Set the text color for the entire figure# Set the background color of the entire figure
)


# # Customize the chart appearance, including setting the background color
# fig.update_layout(
#     title='Famous People Timeline with Events',
#     xaxis_title='Years',
#     yaxis_title='Name',
#     height=800,
#     width=1200,
#     plot_bgcolor='blue',  # Set the background color
# )

# Show the chart
fig.show()
